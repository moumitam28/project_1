# %% [markdown]
# #Data import and Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
list = ['Unnamed: 32', 'id']
data = data.drop(list, axis=1)
data.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
dict = {
    'diagnosis':{
        'B':0,
        'M':1
    }
}   
data=data.replace(dict)
data.head()
# Out:
#    diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          1        17.99  ...          0.4601                  0.11890
# 1          1        20.57  ...          0.2750                  0.08902
# 2          1        19.69  ...          0.3613                  0.08758
# 3          1        11.42  ...          0.6638                  0.17300
# 4          1        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
data['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.6/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from xgboost) (1.18.5)

# %%
from sklearn.model_selection import train_test_split
X = data.drop(['diagnosis'], axis=1)
y = data.diagnosis
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.5)

from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

SVM = SVC()
RFC = RandomForestClassifier()
XGB = XGBClassifier()

SVM.fit(x_train, y_train)
print('SVM Score:', SVM.score(x_test,y_test))
RFC.fit(x_train, y_train)
print('RFC Score:', RFC.score(x_test,y_test))
XGB.fit(x_train, y_train)
print('XGB Score:', XGB.score(x_test,y_test))
# Out:
# SVM Score: 0.9157894736842105
# RFC Score: 0.9719298245614035
# XGB Score: 0.968421052631579

# %% [markdown]
# #Running 10 fold Cross Validation on the data

# %%
from sklearn.model_selection import train_test_split
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score



X = data.drop(['diagnosis'], axis=1)
y = data.diagnosis
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.5)
cv = KFold(n_splits=10, random_state=1, shuffle=True)
cv1 = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)


from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB


SVM = SVC()
RFC = RandomForestClassifier()
XGB = XGBClassifier()
KNN=KNeighborsClassifier()
NB=GaussianNB()
scores = cross_val_score(SVM, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
#scores1 = cross_val_score(SVM, X, y, scoring='accuracy', cv=cv1, n_jobs=-1)
print('SVM Accuracy 10 fold: %.4f (%.3f)' % (mean(scores)*100, std(scores)))
#print('SVM Accuracy Repeated 10 fold: %.3f (%.3f)' % (mean(scores1), std(scores1)))
scores = cross_val_score(RFC, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
#scores1 = cross_val_score(RFC, X, y, scoring='accuracy', cv=cv1, n_jobs=-1)
print('RFC Accuracy 10 fold: %.4f (%.3f)' % (mean(scores)*100, std(scores)))
#print('RFC Accuracy Repeated 10 fold: %.3f (%.3f)' % (mean(scores1), std(scores1)))
scores = cross_val_score(XGB, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
#scores1 = cross_val_score(XGB, X, y, scoring='accuracy', cv=cv1, n_jobs=-1)
print('XGB Accuracy 10 fold: %.4f (%.3f)' % (mean(scores)*100, std(scores)))
#print('XGB Accuracy Repeated 10 fold: %.3f (%.3f)' % (mean(scores1), std(scores1)))
scores = cross_val_score(KNN, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
#scores1 = cross_val_score(KNN, X, y, scoring='accuracy', cv=cv1, n_jobs=-1)
print('KNN Accuracy 10 fold: %.4f (%.3f)' % (mean(scores)*100, std(scores)))
#print('KNN Accuracy Repeated 10 fold: %.3f (%.3f)' % (mean(scores1), std(scores1)))
scores = cross_val_score(NB, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Naive Bayes Accuracy 10 fold: %.4f (%.3f)' % (mean(scores)*100, std(scores)))
'''SVM Accuracy 10 fold: 91.3753 (0.043)
RFC Accuracy 10 fold: 96.4818 (0.018)
XGB Accuracy 10 fold: 96.8358 (0.017)
KNN Accuracy 10 fold: 92.9637 (0.039)
Naive Bayes Accuracy 10 fold: 94.1980 (0.026)'''
# Out:
# SVM Accuracy 10 fold: 91.3753 (0.043)
# RFC Accuracy 10 fold: 95.7801 (0.023)
# XGB Accuracy 10 fold: 96.8358 (0.017)
# KNN Accuracy 10 fold: 92.9637 (0.039)
# Naive Bayes Accuracy 10 fold: 94.1980 (0.026)
# 'SVM Accuracy 10 fold: 91.3753 (0.043)\nRFC Accuracy 10 fold: 96.4818 (0.018)\nXGB Accuracy 10 fold: 96.8358 (0.017)\nKNN Accuracy 10 fold: 92.9637 (0.039)\nNaive Bayes Accuracy 10 fold: 94.1980 (0.026)'

# %% [markdown]
# #Filter Assembling

# %%
#Chi-Square Test

import scipy.stats as stats
from scipy.stats import chi2

def chi_sqr(test_column,output_column):
    observed_value = pd.crosstab(test_column,output_column)
    val = stats.chi2_contingency(observed_value)
    expected_value=val[3]
    no_of_rows=len(observed_value.iloc[0:2,0])
    no_of_columns=len(observed_value.iloc[0,0:2])
    dgof=(no_of_rows-1)*(no_of_columns-1)
    alpha=0.05
    for o,e in zip(observed_value.values,expected_value):
        chi_2 = sum([(o-e)**2./e])       
    chi2_stat = np.sum(chi_2)
    return chi2_stat
    
df1 = data.drop(['diagnosis'], axis=1)
top_n1 =[]
for i in df1.columns.values:
    top_n1.append(chi_sqr(df1[i],data['diagnosis']))
    
col_name1 = np.array(X.columns)
a1 = pd.DataFrame(top_n1)
b1 = pd.DataFrame(col_name1)
info1 = pd.concat([a1,b1], axis=1)
info1.columns = ['Score','Features']

top1 = info1.nsmallest(20,'Score')
ft1 = np.array(top1['Features'])
top1
ft1
# Out:
# array(['smoothness_mean', 'texture_se', 'concavity_se',
#        'concave points_se', 'fractal_dimension_se', 'concavity_worst',
#        'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'compactness_mean', 'concavity_mean', 'concave points_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'radius_se',
#        'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se'],
#       dtype=object)

# %%
pip install skrebate

# %%
#ReliefF

from sklearn.pipeline import make_pipeline
from skrebate import ReliefF

features, classes = data.drop('diagnosis', axis=1).values, data['diagnosis'].values
X_train, X_test, y_train, y_test = train_test_split(features, classes)

arr = X_train.astype('float64')
fs = ReliefF()
fs.fit(arr, y_train)

top_n2=[]
names=[]
for feature_name, feature_score in zip(data.drop('diagnosis', axis=1).columns, fs.feature_importances_):
    top_n2.append(feature_score)
    names.append(feature_name)
    
col_name3 = np.array(data.columns)
a3 = pd.DataFrame(top_n2)
b3 = pd.DataFrame(col_name3)
b4 =pd.DataFrame(names)

info3 = pd.concat([a3,b3], axis=1)
info3.columns = ['Score','Features'] 

inf3 = pd.concat([a3,b4], axis=1)
inf3.columns = ['Score','Features']

top3 = inf3.nlargest(20,'Score')
ft3 = np.array(top3['Features'])
ft3
# Out:
# array(['concave points_worst', 'radius_worst', 'perimeter_worst',
#        'concave points_mean', 'area_worst', 'perimeter_mean',
#        'radius_mean', 'concavity_mean', 'area_mean', 'concavity_worst',
#        'compactness_worst', 'compactness_mean', 'radius_se',
#        'smoothness_worst', 'texture_worst', 'area_se', 'perimeter_se',
#        'texture_mean', 'symmetry_worst', 'concave points_se'],
#       dtype=object)

# %%
#Information Gain/Mutual Information

from sklearn.feature_selection import mutual_info_classif

res = mutual_info_classif(X,y,discrete_features=True)

col_name2 = np.array(X.columns)

a2 = pd.DataFrame(res)
b2 = pd.DataFrame(col_name2)
info2 = pd.concat([a2,b2], axis=1)
info2.columns = ['Info_Gain','Features']

top2 = info2.nlargest(20,'Info_Gain')
ft2 = np.array(top2['Features'])
ft2
# Out:
# array(['concave points_mean', 'concavity_mean', 'smoothness_se',
#        'area_worst', 'radius_se', 'perimeter_se', 'concavity_worst',
#        'area_mean', 'concavity_se', 'perimeter_mean', 'area_se',
#        'compactness_se', 'compactness_worst', 'fractal_dimension_se',
#        'concave points_worst', 'compactness_mean', 'radius_worst',
#        'perimeter_worst', 'fractal_dimension_worst', 'texture_se'],
#       dtype=object)

# %% [markdown]
# *Union Function*

# %%
def top_fs_union(n):
    f1 = ft1[:n]
    f2 = ft2[:n]
    f3 = ft3[:n]
    a=reduce(np.union1d, (f1,f2,f3))
    print (a)
    return(a)

# %% [markdown]
# *Classifier function call with selected top n*

# %%
def assemble_run(n,classifier):
  top_fs=top_fs_union(n)
  top_fs=np.append(top_fs,['diagnosis'], axis=0)
  dfs = data.loc[:,top_fs]
  X = dfs.drop(['diagnosis'], axis=1)
  y = dfs['diagnosis']
  model = classifier()
  scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
  print('Accuracy 10 fold: %.4f (%.3f)' % (mean(scores)*100, std(scores)),end='\n')
  print('\n\n')

# %%
#RANDOM FOREST CLASSIFIER

#Feature Subset by Union of 5 Best Features from each
RFC1 = assemble_run(5,RandomForestClassifier)
#Feature Subset by Union of 8 Best Features from each
RFC2 = assemble_run(8,RandomForestClassifier)
#Feature Subset by Union of 10 Best Features from each
RFC3 = assemble_run(10,RandomForestClassifier)
#Feature Subset by Union of 15 Best Features from each
RFC4 = assemble_run(15,RandomForestClassifier)
#Feature Subset by Union of 20 Best Features from each
RFC5 = assemble_run(20,RandomForestClassifier)
# Out:
# ['area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se'
#  'fractal_dimension_se' 'perimeter_worst' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'texture_se']
# Accuracy 10 fold: 94.7243 (0.022)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 95.6046 (0.021)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 95.6046 (0.023)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'perimeter_mean'
#  'perimeter_se' 'perimeter_worst' 'radius_mean' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'smoothness_worst' 'symmetry_mean'
#  'texture_mean' 'texture_se' 'texture_worst']
# Accuracy 10 fold: 96.1341 (0.022)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'fractal_dimension_worst'
#  'perimeter_mean' 'perimeter_se' 'perimeter_worst' 'radius_mean'
#  'radius_se' 'radius_worst' 'smoothness_mean' 'smoothness_se'
#  'smoothness_worst' 'symmetry_mean' 'symmetry_worst' 'texture_mean'
#  'texture_se' 'texture_worst']
# Accuracy 10 fold: 96.6604 (0.021)

# %%
#XG BOOST CLASSIFIER

#Feature Subset by Union of 5 Best Features from each
XGB1 = assemble_run(5,XGBClassifier)
#Feature Subset by Union of 8 Best Features from each
XGB2 = assemble_run(8,XGBClassifier)
#Feature Subset by Union of 10 Best Features from each
XGB3 = assemble_run(10,XGBClassifier)
#Feature Subset by Union of 15 Best Features from each
XGB4 = assemble_run(15,XGBClassifier)
#Feature Subset by Union of 20 Best Features from each
XGB5 = assemble_run(20,XGBClassifier)
#Feature Subset by Union of 5 Best Features from each
# Out:
# ['area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se'
#  'fractal_dimension_se' 'perimeter_worst' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'texture_se']
# Accuracy 10 fold: 94.5520 (0.015)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 96.6604 (0.017)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 96.6604 (0.017)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'perimeter_mean'
#  'perimeter_se' 'perimeter_worst' 'radius_mean' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'smoothness_worst' 'symmetry_mean'
#  'texture_mean' 'texture_se' 'texture_worst']
# Accuracy 10 fold: 97.0113 (0.016)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'fractal_dimension_worst'
#  'perimeter_mean' 'perimeter_se' 'perimeter_worst' 'radius_mean'
#  'radius_se' 'radius_worst' 'smoothness_mean' 'smoothness_se'
#  'smoothness_worst' 'symmetry_mean' 'symmetry_worst' 'texture_mean'
#  'texture_se' 'texture_worst']
# Accuracy 10 fold: 96.8358 (0.017)

# %%
#KNN CLASSIFIER

#Feature Subset by Union of 5 Best Features from each
KNN1 = assemble_run(5,KNeighborsClassifier)
#Feature Subset by Union of 8 Best Features from each
KNN2 = assemble_run(8,KNeighborsClassifier)
#Feature Subset by Union of 10 Best Features from each
KNN3 = assemble_run(10,KNeighborsClassifier)
#Feature Subset by Union of 15 Best Features from each
KNN4 = assemble_run(15,KNeighborsClassifier)
#Feature Subset by Union of 20 Best Features from each
KNN5 = assemble_run(20,KNeighborsClassifier)
#Feature Subset by Union of 5 Best Features from each
# Out:
# ['area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se'
#  'fractal_dimension_se' 'perimeter_worst' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'texture_se']
# Accuracy 10 fold: 89.9749 (0.042)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 92.6128 (0.041)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 92.6128 (0.041)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'perimeter_mean'
#  'perimeter_se' 'perimeter_worst' 'radius_mean' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'smoothness_worst' 'symmetry_mean'
#  'texture_mean' 'texture_se' 'texture_worst']
# Accuracy 10 fold: 92.9637 (0.039)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'fractal_dimension_worst'
#  'perimeter_mean' 'perimeter_se' 'perimeter_worst' 'radius_mean'
#  'radius_se' 'radius_worst' 'smoothness_mean' 'smoothness_se'
#  'smoothness_worst' 'symmetry_mean' 'symmetry_worst' 'texture_mean'
#  'texture_se' 'texture_worst']
# Accuracy 10 fold: 92.9637 (0.039)

# %%
#Naive Bayes CLASSIFIER

#Feature Subset by Union of 5 Best Features from each
NB1 = assemble_run(5,GaussianNB)
#Feature Subset by Union of 8 Best Features from each
NB2 = assemble_run(8,GaussianNB)
#Feature Subset by Union of 10 Best Features from each
NB3 = assemble_run(10,GaussianNB)
#Feature Subset by Union of 15 Best Features from each
NB4 = assemble_run(15,GaussianNB)
#Feature Subset by Union of 20 Best Features from each
NB5 = assemble_run(20,GaussianNB)
#Feature Subset by Union of 5 Best Features from each
# Out:
# ['area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se'
#  'fractal_dimension_se' 'perimeter_worst' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'texture_se']
# Accuracy 10 fold: 94.5489 (0.024)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 92.9637 (0.030)
#
#
#
# ['area_mean' 'area_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_se' 'perimeter_mean' 'perimeter_se' 'perimeter_worst'
#  'radius_mean' 'radius_se' 'radius_worst' 'smoothness_mean'
#  'smoothness_se' 'texture_mean' 'texture_se']
# Accuracy 10 fold: 92.9637 (0.030)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'perimeter_mean'
#  'perimeter_se' 'perimeter_worst' 'radius_mean' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'smoothness_worst' 'symmetry_mean'
#  'texture_mean' 'texture_se' 'texture_worst']
# Accuracy 10 fold: 93.8440 (0.025)
#
#
#
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'fractal_dimension_worst'
#  'perimeter_mean' 'perimeter_se' 'perimeter_worst' 'radius_mean'
#  'radius_se' 'radius_worst' 'smoothness_mean' 'smoothness_se'
#  'smoothness_worst' 'symmetry_mean' 'symmetry_worst' 'texture_mean'
#  'texture_se' 'texture_worst']
# Accuracy 10 fold: 94.0226 (0.025)

# %% [markdown]
# *Checking No of feaures for best accuracy*

# %%
print(len(top_fs_union(15)))
# Out:
# ['area_mean' 'area_se' 'area_worst' 'compactness_mean' 'compactness_se'
#  'compactness_worst' 'concave points_mean' 'concave points_se'
#  'concave points_worst' 'concavity_mean' 'concavity_se' 'concavity_worst'
#  'fractal_dimension_mean' 'fractal_dimension_se' 'perimeter_mean'
#  'perimeter_se' 'perimeter_worst' 'radius_mean' 'radius_se' 'radius_worst'
#  'smoothness_mean' 'smoothness_se' 'smoothness_worst' 'symmetry_mean'
#  'texture_mean' 'texture_se' 'texture_worst']
# 27
